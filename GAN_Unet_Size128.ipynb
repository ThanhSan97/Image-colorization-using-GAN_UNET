# %% [markdown]
# # BUILDING AN AUTOMATED IMAGE COLORIZATION MODEL - GAN-UNET![colorize-black-and-white-female-portrait-with-fotor-online-ai-photo-colorizer.webp](data:image/webp;base64,...)

# %% [markdown]
# **Import Library**

# %%
import glob
import numpy as np
from PIL import Image

import torch
from torch import nn, optim
from torchvision import transforms
from torchvision.utils import make_grid
from torch.utils.data import Dataset, DataLoader
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
use_colab = None

# %% [markdown]
# #**I. Load data**

# %% [markdown]
# ##**1. Connect to Google Drive to get Dataset**
# Please download the dataset of human faces from the provided Google Drive link on GitHub and upload it to your Google Drive for usage in this document.
#
# *   Dataset: https://drive.google.com/drive/folders/1R1cceF-7gmaeG20WTvy2ima-oCptnNbD?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the directory containing the dataset on Google Drive
dataset_path = '/content/drive/MyDrive/Đồ-án-CDIO/CDIO4 - ToMauHinhAnh-GanUnet/Dataset' #path to your dataset
use_colab = True

# %% [markdown]
# ##**2. Load image from Dataset on Google Drive**

# %%
import os
from tqdm.notebook import tqdm
from pathlib import Path

if use_colab == True:
    path = dataset_path
else:
    path = "Your path to the dataset"
def images_upload(path):
    images=[]
    for root,subfolders,files in os.walk(path):
        for file in tqdm(files):
            filename=root+os.sep+file
            if filename.endswith('jpg') or filename.endswith('png'):
                images.append(filename)
    images = images[0:2000]
    # return  np.random.choice(images, 1000)
    return  np.array(images)
images=images_upload(path)
print(images.shape)
print(images)
# Out:
#   0%|          | 0/5490 [00:00<?, ?it/s]
# (2000,)
# ['/content/drive/MyDrive/Đồ-án-CDIO/CDIO4 - ToMauHinhAnh-GanUnet/Dataset/1 (4932).jpg'
#  '/content/drive/MyDrive/Đồ-án-CDIO/CDIO4 - ToMauHinhAnh-GanUnet/Dataset/1 (4964).jpg'
#  '/content/drive/MyDrive/Đồ-án-CDIO/CDIO4 - ToMauHinhAnh-GanUnet/Dataset/1 (4954).jpg'
#  ...
#  '/content/drive/MyDrive/Đồ-án-CDIO/CDIO4 - ToMauHinhAnh-GanUnet/Dataset/1 (3219).jpg'
#  '/content/drive/MyDrive/Đồ-án-CDIO/CDIO4 - ToMauHinhAnh-GanUnet/Dataset/1 (3211).jpg'
#  '/content/drive/MyDrive/Đồ-án-CDIO/CDIO4 - ToMauHinhAnh-GanUnet/Dataset/1 (32).jpg']

# %% [markdown]
# #**3. Convert data into input and label sets**

# %%
SIZE = 128

# %%
import cv2
from skimage.color import rgb2lab, lab2rgb

def convert_image_labels(images):
    labels=[]
    for i in tqdm(images):
        i = cv2.imread(i)
        i=cv2.cvtColor(i, cv2.COLOR_BGR2RGB)
        res_i=cv2.resize(i,(SIZE,SIZE))
        del i
        labels.append(res_i)
    return labels


def convert_image_inputs(images):
    inputs=[]
    for z in tqdm(images):
        z = cv2.imread(z)
        z=cv2.cvtColor(z,  cv2.COLOR_BGR2GRAY)
        res_z=cv2.resize(z,(SIZE,SIZE))
        del z
        inputs.append(res_z)
    return inputs

labels=convert_image_labels(images)
inputs=convert_image_inputs(images)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
def convert_image_inputs(images):
    labels = []
    for image_path in images:
        img = cv2.imread(image_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            res_img = cv2.resize(img, (SIZE, SIZE))
            labels.append(res_img)
    return labels
labels=convert_image_labels(images)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt

# %%
def show_labels(labels):
    plt.figure(figsize=(10,10))
    for i in range(9):
        idx=np.random.randint(0,len(labels))
        plt.subplot(3,3,i+1)
        img=labels[idx]
        plt.imshow(img)

show_labels(labels)

# %%
def show_input(inputs):
    plt.figure(figsize=(10,10))
    for i in range(9):
        idx=np.random.randint(0,len(inputs))
        plt.subplot(3,3,i+1)
        img=inputs[idx]
        plt.imshow(img,cmap='gray')
show_input(inputs)

# %%
def images_compare(inputs,labels):
    idx_new=np.random.randint(0,len(labels))
    fig = plt.figure()
    ax1 = fig.add_subplot(1,2,1)
    ax1.imshow(inputs[idx_new],cmap='gray')
    ax2 = fig.add_subplot(1,2,2)
    ax2.imshow(labels[idx_new])
    plt.show()
images_compare(inputs,labels)

# %% [markdown]
# #**4. Split data to Train/Test set**

# %%
from sklearn.model_selection import train_test_split

def split_data(inputs,labels,test_size=0.2):
    labels=np.array(labels)
    inputs=np.array(inputs)
    x_train, x_test, y_train, y_test = train_test_split(inputs, labels, test_size=test_size)
    return x_train, x_test ,y_train,y_test

# %%
x_train,x_test ,y_train, y_test=split_data(inputs,labels,test_size=0.2)
x_train, x_test=x_train/255.0,x_test/255.0
y_train, y_test=y_train/255.0,y_test/255.0

# %% [markdown]
# #**Build model GAN-Unet**

# %% [markdown]
# ##**1. Build GENERATOR(Unet)**

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    BatchNormalization, Conv2D, Conv2DTranspose, Dense,
    Flatten, Dropout, UpSampling2D, Concatenate, ELU,
    Input, LeakyReLU, MaxPooling2D, Reshape, UpSampling2D)
from tensorflow.keras.models import Model
import tensorflow.keras.layers as tfl
from tensorflow.keras.optimizers import Adam

# %%
#GEN 128x128

# %%
def build_generator(inputsize=(128, 128, 1)):
    input = Input(shape=inputsize)

    x = Conv2D(64, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv1')(input)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(64, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv2')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x1 = Conv2D(64, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv3')(x)
    x = BatchNormalization()(x1)
    x = LeakyReLU()(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool1')(x)

    x = Conv2D(128, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv4')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(128, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv5')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x2 = Conv2D(128, (3, 3), padding="same", strides=(1, 1), kernel_initializer='he_normal', name='Conv6')(x)
    x = BatchNormalization()(x2)
    x = LeakyReLU()(x)
    x = MaxPooling2D(pool_size=(2, 2), name='MaxPool2')(x)

    x = Conv2D(256, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv7')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(256, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv8')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x3 = Conv2D(256, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv9')(x)
    x = BatchNormalization()(x3)
    x = LeakyReLU()(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool3')(x)

    x = Conv2D(512, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv10')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(512, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv11')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x4 = Conv2D(512, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv12')(x)
    x = BatchNormalization()(x4)
    x = LeakyReLU()(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool4')(x)

    x = Conv2D(1024, (3, 3), padding="same", name='Conv13')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(1024, (3, 3), padding="same", name='Conv14')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(1024, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv15')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(512, (3, 3), strides=2, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = concatenate([x, x4], axis=3)

    x = Conv2D(512, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv16')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(512, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv17')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(512, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv18')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(256, (3, 3), strides=2, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = concatenate([x, x3], axis=3)

    x = Conv2D(256, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv19')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(256, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv20')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(256, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv21')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(128, (3, 3), strides=2, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = concatenate([x, x2], axis=3)

    x = Conv2D(128, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv22')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(128, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv23')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(128, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv24')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2DTranspose(64, (3, 3), strides=2, padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = concatenate([x, x1], axis=3)

    x = Conv2D(64, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv25')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(64, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv26')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = Conv2D(64, (3, 3), padding="same", kernel_initializer='he_normal', name='Conv27')(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    outputs = Conv2D(3, (1, 1), padding="same", activation='tanh', name='Generator_Output')(x)

    generator_model = tf.keras.Model(inputs=input, outputs=outputs)
    generator_model.summary()
    return generator_model

# %%
generator = build_generator(inputsize=(SIZE, SIZE, 1))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 1)]        0         []
#
#  Conv1 (Conv2D)              (None, 128, 128, 64)         640       ['input_3[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['Conv1[0][0]']
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  Conv2 (Conv2D)              (None, 128, 128, 64)         36928     ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 128, 64)         256       ['Conv2[0][0]']
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 128, 128, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  Conv3 (Conv2D)              (None, 128, 128, 64)         36928     ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 64)         256       ['Conv3[0][0]']
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128, 128, 64)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  MaxPool1 (MaxPooling2D)     (None, 64, 64, 64)           0         ['leaky_re_lu_3[0][0]']
#
#  Conv4 (Conv2D)              (None, 64, 64, 128)          73856     ['MaxPool1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 128)          512       ['Conv4[0][0]']
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64, 64, 128)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  Conv5 (Conv2D)              (None, 64, 64, 128)          147584    ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 64, 128)          512       ['Conv5[0][0]']
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 64, 64, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  Conv6 (Conv2D)              (None, 64, 64, 128)          147584    ['leaky_re_lu_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['Conv6[0][0]']
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  MaxPool2 (MaxPooling2D)     (None, 32, 32, 128)          0         ['leaky_re_lu_6[0][0]']
#
#  Conv7 (Conv2D)              (None, 32, 32, 256)          295168    ['MaxPool2[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 256)          1024      ['Conv7[0][0]']
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 32, 32, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  Conv8 (Conv2D)              (None, 32, 32, 256)          590080    ['leaky_re_lu_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 32, 32, 256)          1024      ['Conv8[0][0]']
#  chNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 32, 32, 256)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  Conv9 (Conv2D)              (None, 32, 32, 256)          590080    ['leaky_re_lu_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 256)          1024      ['Conv9[0][0]']
#  chNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 32, 32, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  MaxPool3 (MaxPooling2D)     (None, 16, 16, 256)          0         ['leaky_re_lu_9[0][0]']
#
#  Conv10 (Conv2D)             (None, 16, 16, 512)          1180160   ['MaxPool3[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 512)          2048      ['Conv10[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 16, 16, 512)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  Conv11 (Conv2D)             (None, 16, 16, 512)          2359808   ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 512)          2048      ['Conv11[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 16, 16, 512)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  Conv12 (Conv2D)             (None, 16, 16, 512)          2359808   ['leaky_re_lu_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 512)          2048      ['Conv12[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 16, 16, 512)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  MaxPool4 (MaxPooling2D)     (None, 8, 8, 512)            0         ['leaky_re_lu_12[0][0]']
#
#  Conv13 (Conv2D)             (None, 8, 8, 1024)           4719616   ['MaxPool4[0][0]']
#
#  batch_normalization_13 (Ba  (None, 8, 8, 1024)           4096      ['Conv13[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 8, 8, 1024)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  Conv14 (Conv2D)             (None, 8, 8, 1024)           9438208   ['leaky_re_lu_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 8, 8, 1024)           4096      ['Conv14[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 8, 8, 1024)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  Conv15 (Conv2D)             (None, 8, 8, 1024)           9438208   ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 8, 8, 1024)           4096      ['Conv15[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 8, 8, 1024)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 16, 512)          4719104   ['leaky_re_lu_15[0][0]']
#  anspose)
#
#  batch_normalization_16 (Ba  (None, 16, 16, 512)          2048      ['conv2d_transpose[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 16, 16, 512)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  concatenate_1 (Concatenate  (None, 16, 16, 1024)         0         ['leaky_re_lu_16[0][0]',
#  )                                                                   'Conv12[0][0]']
#
#  Conv16 (Conv2D)             (None, 16, 16, 512)          4719104   ['concatenate_1[0][0]']
#
#  batch_normalization_17 (Ba  (None, 16, 16, 512)          2048      ['Conv16[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 16, 16, 512)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  Conv17 (Conv2D)             (None, 16, 16, 512)          2359808   ['leaky_re_lu_17[0][0]']
#
#  batch_normalization_18 (Ba  (None, 16, 16, 512)          2048      ['Conv17[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 16, 16, 512)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  Conv18 (Conv2D)             (None, 16, 16, 512)          2359808   ['leaky_re_lu_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 16, 16, 512)          2048      ['Conv18[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 16, 16, 512)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 32, 256)          1179904   ['leaky_re_lu_19[0][0]']
#  Transpose)
#
#  batch_normalization_20 (Ba  (None, 32, 32, 256)          1024      ['conv2d_transpose_1[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 32, 32, 256)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  concatenate_2 (Concatenate  (None, 32, 32, 512)          0         ['leaky_re_lu_20[0][0]',
#  )                                                                   'Conv9[0][0]']
#
#  Conv19 (Conv2D)             (None, 32, 32, 256)          1179904   ['concatenate_2[0][0]']
#
#  batch_normalization_21 (Ba  (None, 32, 32, 256)          1024      ['Conv19[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 32, 32, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  Conv20 (Conv2D)             (None, 32, 32, 256)          590080    ['leaky_re_lu_21[0][0]']
#
#  batch_normalization_22 (Ba  (None, 32, 32, 256)          1024      ['Conv20[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 32, 32, 256)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  Conv21 (Conv2D)             (None, 32, 32, 256)          590080    ['leaky_re_lu_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 32, 32, 256)          1024      ['Conv21[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 32, 32, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 64, 128)          295040    ['leaky_re_lu_23[0][0]']
#  Transpose)
#
#  batch_normalization_24 (Ba  (None, 64, 64, 128)          512       ['conv2d_transpose_2[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 64, 64, 128)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  concatenate_3 (Concatenate  (None, 64, 64, 256)          0         ['leaky_re_lu_24[0][0]',
#  )                                                                   'Conv6[0][0]']
#
#  Conv22 (Conv2D)             (None, 64, 64, 128)          295040    ['concatenate_3[0][0]']
#
#  batch_normalization_25 (Ba  (None, 64, 64, 128)          512       ['Conv22[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 64, 64, 128)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  Conv23 (Conv2D)             (None, 64, 64, 128)          147584    ['leaky_re_lu_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 64, 64, 128)          512       ['Conv23[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 64, 64, 128)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  Conv24 (Conv2D)             (None, 64, 64, 128)          147584    ['leaky_re_lu_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 64, 64, 128)          512       ['Conv24[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 64, 64, 128)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 128, 64)         73792     ['leaky_re_lu_27[0][0]']
#  Transpose)
#
#  batch_normalization_28 (Ba  (None, 128, 128, 64)         256       ['conv2d_transpose_3[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 128, 128, 64)         0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 128, 128, 128)        0         ['leaky_re_lu_28[0][0]',
#  )                                                                   'Conv3[0][0]']
#
#  Conv25 (Conv2D)             (None, 128, 128, 64)         73792     ['concatenate_4[0][0]']
#
#  batch_normalization_29 (Ba  (None, 128, 128, 64)         256       ['Conv25[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 128, 128, 64)         0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  Conv26 (Conv2D)             (None, 128, 128, 64)         36928     ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_30 (Ba  (None, 128, 128, 64)         256       ['Conv26[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 128, 128, 64)         0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  Conv27 (Conv2D)             (None, 128, 128, 64)         36928     ['leaky_re_lu_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 128, 128, 64)         256       ['Conv27[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 128, 128, 64)         0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  Generator_Output (Conv2D)   (None, 128, 128, 3)          195       ['leaky_re_lu_31[0][0]']
#
# ==================================================================================================
# Total params: 50258499 (191.72 MB)
# Trainable params: 50238915 (191.65 MB)
# Non-trainable params: 19584 (76.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# **Note:** In this case, we previously trained the GAN-Unet model with SIZE=64x64. However, the output may not be of high quality with this size. Therefore, if you want better results, adjust SIZE=128 instead of SIZE=64 and train the model accordingly. Then, save the model as 'generator_model.h5'. Finally, use the two code cells below to transfer the trained weights from the SIZE=64 model to the SIZE=128 model in order to save resources. After successfully completing this process, proceed to run the cells below to obtain the complete GAN-Unet model with SIZE=128.

# %%
# #Load model pre-trained with SIZE=64. To obtain this 'generator_model.h5' model, you just need to modify the SIZE=64 value above and train your dataset
# from tensorflow.keras.models import load_model

# generator_64x64 = load_model('/content/drive/MyDrive/CDIO4/generator_model.h5')
# generator.set_weights(generator_64x64.get_weights())  #Copy weights from the SIZE=64x64 model to the SIZE=128x128 model.

# %% [markdown]
# ##**2. Build DISCRIMINATOR(CNN)**

# %%
def build_discriminator():

    activation = tf.keras.layers.LeakyReLU(alpha=0.2)  # Sử dụng LeakyReLU như Model 1

    inputs = Input(shape=(SIZE, SIZE, 3))  # Điều chỉnh kích thước đầu vào để phù hợp với Model 1

    # Thay đổi các lớp Conv2D để có số lớp và kích thước đầu ra tương tự
    conv1 = Conv2D(64, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = activation(conv1)
    conv1 = Conv2D(64, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = activation(conv1)
    conv1 = MaxPooling2D()(conv1)

    conv2 = Conv2D(128, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv1)
    conv2 = BatchNormalization()(conv2)
    conv2 = activation(conv2)
    conv2 = Conv2D(128, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = activation(conv2)
    conv2 = MaxPooling2D()(conv2)

    conv3 = Conv2D(256, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv2)
    conv3 = BatchNormalization()(conv3)
    conv3 = activation(conv3)
    conv3 = Conv2D(256, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = activation(conv3)
    conv3 = MaxPooling2D()(conv3)

    conv4 = Conv2D(512, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv3)
    conv4 = BatchNormalization()(conv4)
    conv4 = activation(conv4)
    conv4 = Conv2D(512, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = activation(conv4)
    conv4 = MaxPooling2D()(conv4)

    conv5 = Conv2D(1024, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv4)
    conv5 = BatchNormalization()(conv5)
    conv5 = activation(conv5)
    conv5 = Conv2D(1024, kernel_size=(3, 3), strides=1, padding='same', kernel_initializer='he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    conv5 = activation(conv5)

    fully = Flatten()(conv5)
    fully = Dense(512)(fully)
    fully = BatchNormalization()(fully)
    fully = activation(fully)
    fully = Dense(128)(fully)
    fully = BatchNormalization()(fully)
    fully = activation(fully)
    fully = Dense(32)(fully)
    fully = BatchNormalization()(fully)
    fully = activation(fully)
    fully = Dense(1, activation='sigmoid')(fully)

    model = tf.keras.models.Model(inputs, fully)
    model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5), metrics=['accuracy'])
    model.summary()
    return model

# %%
discriminator = build_discriminator()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 64)         1792      ['input_4[0][0]']
#
#  batch_normalization_32 (Ba  (None, 128, 128, 64)         256       ['conv2d[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_32 (LeakyReLU)  multiple                     0         ['batch_normalization_32[0][0]
#                                                                     ',
#                                                                      'batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'batch_normalization_34[0][0]
#                                                                     ',
#                                                                      'batch_normalization_35[0][0]
#                                                                     ',
#                                                                      'batch_normalization_36[0][0]
#                                                                     ',
#                                                                      'batch_normalization_37[0][0]
#                                                                     ',
#                                                                      'batch_normalization_38[0][0]
#                                                                     ',
#                                                                      'batch_normalization_39[0][0]
#                                                                     ',
#                                                                      'batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'batch_normalization_41[0][0]
#                                                                     ',
#                                                                      'batch_normalization_42[0][0]
#                                                                     ',
#                                                                      'batch_normalization_43[0][0]
#                                                                     ',
#                                                                      'batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)         36928     ['leaky_re_lu_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 128, 128, 64)         256       ['conv2d_1[0][0]']
#  tchNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 64)           0         ['leaky_re_lu_32[1][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)          73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_34 (Ba  (None, 64, 64, 128)          512       ['conv2d_2[0][0]']
#  tchNormalization)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 128)          147584    ['leaky_re_lu_32[2][0]']
#
#  batch_normalization_35 (Ba  (None, 64, 64, 128)          512       ['conv2d_3[0][0]']
#  tchNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 128)          0         ['leaky_re_lu_32[3][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  batch_normalization_36 (Ba  (None, 32, 32, 256)          1024      ['conv2d_4[0][0]']
#  tchNormalization)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 256)          590080    ['leaky_re_lu_32[4][0]']
#
#  batch_normalization_37 (Ba  (None, 32, 32, 256)          1024      ['conv2d_5[0][0]']
#  tchNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 256)          0         ['leaky_re_lu_32[5][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  batch_normalization_38 (Ba  (None, 16, 16, 512)          2048      ['conv2d_6[0][0]']
#  tchNormalization)
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 512)          2359808   ['leaky_re_lu_32[6][0]']
#
#  batch_normalization_39 (Ba  (None, 16, 16, 512)          2048      ['conv2d_7[0][0]']
#  tchNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 512)            0         ['leaky_re_lu_32[7][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 1024)           4719616   ['max_pooling2d_3[0][0]']
#
#  batch_normalization_40 (Ba  (None, 8, 8, 1024)           4096      ['conv2d_8[0][0]']
#  tchNormalization)
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 1024)           9438208   ['leaky_re_lu_32[8][0]']
#
#  batch_normalization_41 (Ba  (None, 8, 8, 1024)           4096      ['conv2d_9[0][0]']
#  tchNormalization)
#
#  flatten (Flatten)           (None, 65536)                0         ['leaky_re_lu_32[9][0]']
#
#  dense (Dense)               (None, 512)                  3355494   ['flatten[0][0]']
#                                                           4
#
#  batch_normalization_42 (Ba  (None, 512)                  2048      ['dense[0][0]']
#  tchNormalization)
#
#  dense_1 (Dense)             (None, 128)                  65664     ['leaky_re_lu_32[10][0]']
#
#  batch_normalization_43 (Ba  (None, 128)                  512       ['dense_1[0][0]']
#  tchNormalization)
#
#  dense_2 (Dense)             (None, 32)                   4128      ['leaky_re_lu_32[11][0]']
#
#  batch_normalization_44 (Ba  (None, 32)                   128       ['dense_2[0][0]']
#  tchNormalization)
#
#  dense_3 (Dense)             (None, 1)                    33        ['leaky_re_lu_32[12][0]']
#
# ==================================================================================================
# Total params: 52486529 (200.22 MB)
# Trainable params: 52477249 (200.18 MB)
# Non-trainable params: 9280 (36.25 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ##**3. Build a complete GAN model from the two Generator and Discriminator models above**

# %%
def build_gan(generator, discriminator):
    discriminator.trainable = False
    input = tf.keras.Input(shape=(SIZE, SIZE, 1))
    generated_image = generator(input)
    validity = discriminator(generated_image)
    gan = tf.keras.Model(inputs=input, outputs=[generated_image, validity])
    gan.compile(loss=['mse', 'binary_crossentropy'], loss_weights=[0.9999, 0.0001], optimizer='adam')
    gan.summary()
    return gan

gan = build_gan(generator, discriminator)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 128, 128, 1)]     0
#
#  model (Functional)          (None, 128, 128, 3)       50258499
#
#  model_1 (Functional)        (None, 1)                 52486529
#
# =================================================================
# Total params: 102745028 (391.94 MB)
# Trainable params: 50238915 (191.65 MB)
# Non-trainable params: 52506113 (200.29 MB)
# _________________________________________________________________

# %% [markdown]
# #**Train model**

# %%
import time

def train_gan(generator, discriminator, gan, x_train, y_train, epochs=1000, batch_size=64):
    batch_count = x_train.shape[0] // batch_size
    d_loss_list = []  # Danh sách để lưu giá trị loss của discriminator
    g_loss_list = []  # Danh sách để lưu giá trị loss của generator

    for e in range(epochs):
        start_time = time.time()  # Time start

        for _ in range(batch_count):
            idx = np.random.randint(0, x_train.shape[0], batch_size)
            real_images = y_train[idx]
            gray_images = x_train[idx]

            fake_images = generator.predict(gray_images)

            valid = np.ones((batch_size, 1))
            fake = np.zeros((batch_size, 1))

            d_loss_real = discriminator.train_on_batch(real_images, valid)
            d_loss_fake = discriminator.train_on_batch(fake_images, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

            valid = np.ones((batch_size, 1))

            g_loss = gan.train_on_batch(gray_images, [real_images, valid])

        end_time = time.time()  # Time end
        elapsed_time = end_time - start_time

        print(f"Epoch {e}/{epochs}, D Loss: {d_loss[0]}, G Loss: {g_loss[0]}, Time: {elapsed_time:.2f} seconds")

        # Save loss
        d_loss_list.append(d_loss[0])
        g_loss_list.append(g_loss[0])

        # Compute remaining time
        remaining_time = (epochs - e - 1) * elapsed_time
        hours = int(remaining_time // 3600)
        minutes = int((remaining_time % 3600) // 60)
        print(f"Estimated time remaining: {hours} hours {minutes} minutes")

    return d_loss_list, g_loss_list

# %%
num_epochs = 200
d_loss_list, g_loss_list = train_gan(generator, discriminator, gan, x_train, y_train, epochs=num_epochs, batch_size=32)

# %%
import matplotlib.pyplot as plt

def plot_loss(d_loss, g_loss, num_epochs):
    plt.figure(figsize=(10, 5))
    plt.plot(range(num_epochs), d_loss, label="Discriminator Loss")
    plt.plot(range(num_epochs), g_loss, label="Generator Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

plot_loss(d_loss_list, g_loss_list, num_epochs)

# %% [markdown]
# #**Show results**

# %%
def generate_colored_images(generator, gray_images):
    colored_images = generator.predict(gray_images)
    return colored_images

# %%
num_examples_to_generate = len(x_test)
generated_images = generate_colored_images(generator, x_test)

def result_compare(y_test, pred, x_test):
    num_samples = len(y_test)

    for idx in range(num_samples):
        fig = plt.figure()
        ax1 = fig.add_subplot(1, 3, 1)
        ax1.imshow(x_test[idx], cmap='gray')
        ax1.set_title('Input')
        ax2 = fig.add_subplot(1, 3, 2)
        ax2.imshow(pred[idx])
        ax2.set_title('Output')
        ax3 = fig.add_subplot(1, 3, 3)
        ax3.imshow(y_test[idx])
        ax3.set_title('Original image')
        plt.show()

result_compare(y_test, generated_images, x_test)

# %% [markdown]
# #**Save model to deploy to website**

# %%
from tensorflow.keras.models import load_model

generator.save('generator_model.h5')

# %%
from google.colab import files
file_path = '/content/generator_model.h5'
files.download(file_path)
